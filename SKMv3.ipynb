# %% [markdown]
# # Хорошо обусловленные матрицы

# %% [markdown]
# Сначала рассмотрим следующий класс матриц:
# $A=LU$, где $L$, $U$ – случайные нижняя треугольная и верхняя треугольная
# матрицы соответственно с диагональным преобладанием.

# %%
import time
import numpy as np
from numpy import random
import scipy.linalg as linalg
import matplotlib.pyplot as plt
# %matplotlib inline
 
demension= np.arange(10, 1000, 5) #порядки матриц используемые в соотвествующих тестах
conds = [] # для запоминания чисел обусловленности
times = [] # для времени работы cond
times1 = []# для времени работы solve
errors = [] # для относительной ошибки решения
discr = [] # для вычисления критерия невязки решения
for n in demension:
    B = np.random.uniform(-50, 50, (n,n))
    L=np.tril(B)
    B = np.random.uniform(-50, 50, (n,n))
    U=np.triu(B)
    for j in range(0,n): # получение диагонального преобладания
        L[j][j]=n*np.random.uniform(60,200)
    for j in range(0,n): # получение диагонального преобладания
        U[j][j]=n*np.random.uniform(60,200)
    A=L@U
    start = time.monotonic() #замер времени
    cond=np.linalg.cond(A)  # вычисление числа обусловленности
    t=time.monotonic()-start
    conds.append(cond)
    times.append(t)
    x_prec = random.rand(n)#создание случайного вектора x_prec
    b=A@x_prec #генерация правой части системы линейных уравнений
    start=time.monotonic()
    x_comp=linalg.solve(A,b) # решение системы Ax=b
    t = time.monotonic()-start
    times1.append(t)
    error=linalg.norm(x_comp-x_prec)/linalg.norm(x_prec) # вычисление относительной ошибки
    errors.append(error)
    r=linalg.norm(A.dot(x_comp) - b)/linalg.norm(b) #вычисление критерия невязки решения
    discr.append(r)
    
plt.figure(figsize=(10,5))    
plt.semilogy(demension,conds,'.')
plt.xlabel('Порядок матрицы')
plt.ylabel('Числа обусловленности')
plt.title('Зависимость числа обусловленности от порядка матрицы')
pass

# %% [markdown]
# *Числом обусловленности* невырожденной матрицы $A$ называется
# $$
# { cond } А = \| A \|  \cdot \| A^{-1} \|.
# $$
# Если матрица $A$ вырождена, то полагают ${\rm cond} A = \infty$.
# $$
# {\rm cond} A =  {\max_{x\ne 0} \frac{\|A x\|}{\|x\|}} \left/ \,{\min_{x\ne 0}\frac{\|A x\|}{\|x\|}} \right..
# $$
# Таким образом, число обусловленности – это отношение максимального растяжения матрицы к ее минимальному растяжению.
# Число обсуловленности можно рассматривать как меру близости матрицы к вырожденной. Чем больше число обусловленности, тем матрица ближе к вырожденной.
#
# Т.к. число обусловленности матрицы это отношение минимального растяжения к минимальному, то можно сделать вывод, что оно напрямую зависит от порядка матрицы и от диапазона элементов матрицы. Т.е. чем больше порядок матрицы и диапазон её элементов, тем вероятнее что число её обусловленности будет выше, однако не всегда.
#
# Можно наблюдать в выше приведённом графике, что на матрицах малого порядка, число обусловленности крайне мало, но с ростом порядка матриц начало расти и число обусловленности. Это можно объяснить тем, что чем больше порядок матриц, тем больше строк, чем больше строк, тем больше вероятность того, что  $  {\max_{x\ne 0} \frac{\|A x\|}{\|x\|}}.$ будет больше и ${\min_{x\ne 0}\frac{\|A x\|}{\|x\|}}.$ , будет меньше. А тогда их отношение будет больше, и по определению число обусловленности будет больше.

# %%
plt.plot(demension, times,'.r', label = 'cond')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %%
plt.figure(figsize=(10,5))
plt.plot(demension, times1 , '.b', label ='solve')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %% [markdown]
# Такие резльутаты времени работы этих функций вполне очевидны. Так как функция `cond` считает сумму элементов каждой строки и каждый раз сравнивает её с максимальной и минмальной суммой, то примерная сложность работы алгоритма составляет $n^2$.
#
# Функция `solve` решает с.л.у. методом Гаусса, асимптотика примерно $\frac{n^3}{2}$, что эквивалетно $n^3$.Асимптотика функции `solve` больше асимптотитики функции `cond`, однако время работы функции `solve` значительно меньше. Это связано с тем, что`scipy.linalg` всегда скомпилирована с поддержкой BLAS/LAPACK, благодаря чему она может работать быстрее.  а в `numpy.linalg` эта функция опциональна.

# %%
plt.semilogy(demension, errors,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина относительной ошибки")
plt.title("Зависимость")
pass

# %% [markdown]
# Пусть $x$ – некоторый вектор в ${\bf R}^n$, а $\widetilde{x}$ – другой вектор в ${\bf R}^n$, рассматриваемый как приближение к $x$. Тогда *абсолютной ошибкой* называется число
# $$
#    \|\Delta x\| = \|\widetilde{x} - x\|,
# $$
# а *относительной ошибкой* - число
# $$
#    \frac{\|\Delta x\|}{\|x\|} = \frac{\|\widetilde{x} - x\|}{\|x\|}.
# $$
# Из графика видно, что чем больше порядок матрицы, тем больше относительная ошибка. Это Объясняется тем, что числа нецелые. Чем больше порядок, тем больше накопление ошибок округления. Следовательно и относительная ошибка будет больше. Так же следует, что чем больше порядок матрицы, тем меньше вероятность, что компьютер решит её верно.
#
# Хотя, как можно заметить, для хорошо обусловленных матриц относительная ошибка сравнительно невелика невелика.
#
# Оказывается, что в методе Гаусса с выбором ведущего элемента по столбцу эквивалентное возмущение примерно равно $C\cdot \varepsilon_{\rm M}$, где $C$ – некоторая константа, обычно не сильно превосходящая $1$.
# Таким образом,
# $$
# \frac{\| \Delta x \|}{\| x \|} \approx C\cdot {\rm cond} A \cdot \varepsilon_{\rm M}.
# $$
# В нашем случае, при $\varepsilon_{\rm M} \approx 10^{-16}$ и ${\rm cond} A \approx
# 10^{-1}$ получим относительную ошибку около ${\rm cond} A \cdot \varepsilon_{\rm M}\approx 10^{-15}$, т.е. примерно $15$ правильных значащих цифр.

# %%
plt.plot(demension, discr,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина критерия невязки")
plt.title("Зависимость")
pass

# %% [markdown]
# Относительная невязка $\|Ax - b\|/\|b\|$ для случайных с.л.у. $Ax=b$ от числа неизвестных.
# Исходя из графиков можно заметить, что при увелчении порядка матрицы растёт и относительная невязка. Она напрямую свзязана с относительной ошибкой. Так как из-за возникновения округления решений, будем меняться и правая часть c.л.у. b. И чем больше было неточных округлений, тем больше будет разница $\|Ax - b\|/\|b\|$.
# Число обусловленности растет не очень сильно для данных матриц. Для $n=1000$ оно достигает значения порядка $10^1$. Как следствие, получаем небольшие относительные ошиибки порядка $10^{-16}$. Относительные невязки не првеосходят по порядку величины $10^{-15}$.

# %% [markdown]
#  Теперь рассмотрим:  $A=LL^T$, где $L$ – случайные нижняя треугольная матрица с диагональным преобладанием.

# %%
demension= np.arange(10, 1000, 5) #порядки матриц используемые в соотвествующих тестах
conds = [] # для запоминания чисел обусловленности
times = [] # для времени работы cond
times1 = []# для времени работы solve
errors = [] # для относительной ошибки решения
discr = [] # для вычисления критерия невязки решения
for n in demension:
    B = np.random.uniform(-50, 50, (n,n))
    L=np.tril(B)
    for j in range(0,n): # получение диагонального преобладания
        L[j][j]=n*np.random.uniform(60,200)
    A=L@L.T
    start = time.monotonic() #замер времени
    cond=np.linalg.cond(A)  # вычисление числа обусловленности
    t=time.monotonic()-start
    conds.append(cond)
    times.append(t)
    x_prec = random.rand(n)#создание случайного вектора x_prec
    b=A@x_prec #генерация правой части системы линейных уравнений
    start=time.monotonic()
    x_comp=linalg.solve(A,b) # решение системы Ax=b
    t = time.monotonic()-start
    times1.append(t)
    error=linalg.norm(x_comp-x_prec)/linalg.norm(x_prec) # вычисление относительной ошибки
    errors.append(error)
    r=linalg.norm(A.dot(x_comp) - b)/linalg.norm(b) #вычисление критерия невязки решения
    discr.append(r)
    
plt.figure(figsize=(10,5))    
plt.semilogy(demension,conds,'.')
plt.xlabel('Порядок матрицы')
plt.ylabel('Числа обусловленности')
plt.title('Зависимость числа обусловленности от порядка матрицы')
pass

# %% [markdown]
# Числа обусловленности класса матриц $A=LL^T$ ничем не отличаются от чисел обусловленности класса матриц $A=LU$, где $L$ и $U$ нижняя треугольная и верхняя треугольная матрицы с диагональным преобладанием.

# %%
plt.plot(demension, times,'.r', label = 'cond')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %%
plt.plot(demension, times1 , '.b', label ='solve')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %% [markdown]
# Функции `solve` и `cond`  в среднем отработала за такое же время, что и для класса матриц $A=LU$.

# %%
plt.semilogy(demension, errors,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина относительной ошибки")
plt.title("Зависимость")
pass

# %% [markdown]
# Так как число обусловленности такое же, как и для $A=LU$, примерно $10^1$, то и величина относительной ошибки такая же, не превосходит $10^{-15}$

# %%
plt.plot(demension, discr,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина критерия невязки")
plt.title("Зависимость")
pass

# %% [markdown]
# Относительные невязки не првеосходят по порядку величины $10^{-15}$.

# %% [markdown]
# # Плохо обусловленые матрицы

# %% [markdown]
# Рассмотрим: $A=LU$, где $L$, $U$ – случайные нижняя треугольная и верхняя треугольная
# матрицы соответственно с малыми диагональными элементами.

# %%
demension= np.arange(10, 1000, 5) #порядки матриц используемые в соотвествующих тестах
conds = [] # для запоминания чисел обусловленности
times = [] # для времени работы cond
times1 = []# для времени работы solve
errors = [] # для относительной ошибки решения
discr = [] # для вычисления критерия невязки решения
for n in demension:
    B = np.random.uniform(-40, 40, (n,n))
    L=np.tril(B)
    B = np.random.uniform(-40, 40, (n,n))
    U=np.triu(B)
    A=L@U
    start = time.monotonic() #замер времени
    cond=np.linalg.cond(A)  # вычисление числа обусловленности
    t=time.monotonic()-start
    conds.append(cond)
    times.append(t)
    x_prec = random.rand(n)#создание случайного вектора x_prec
    b=A@x_prec #генерация правой части системы линейных уравнений
    start=time.monotonic()
    x_comp=linalg.solve(A,b) # решение системы Ax=b
    t = time.monotonic()-start
    times1.append(t)
    error=linalg.norm(x_comp-x_prec)/linalg.norm(x_prec) # вычисление относительной ошибки
    errors.append(error)
    r=linalg.norm(A.dot(x_comp) - b)/linalg.norm(b) #вычисление критерия невязки решения
    discr.append(r)
    
plt.figure(figsize=(10,5))    
plt.semilogy(demension,conds,'.')
plt.xlabel('Порядок матрицы')
plt.ylabel('Числа обусловленности')
plt.title('Зависимость числа обусловленности от порядка матрицы')
pass
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.29397e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.90404e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.22908e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.28314e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.28848e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.83676e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.42847e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.91297e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.59938e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.94242e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.12118e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.78464e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.66718e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.28187e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.57657e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.43302e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.41744e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.05749e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.86264e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.80929e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.41547e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.30465e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.66701e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.03838e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.01443e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.74927e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.96007e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.7422e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.31683e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.12107e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.9554e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.36398e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.53956e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.90202e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.7217e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.54043e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.0677e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.75489e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.28486e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.83453e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.57353e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.22733e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.22382e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.8027e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.59758e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.91042e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.01886e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.98362e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.84612e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.07347e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.85347e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.68819e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.32198e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.51225e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.28225e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.67774e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.02903e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.50694e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.39933e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.29378e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.41353e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.77867e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.32969e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.2729e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.8511e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.31927e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.03136e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.5781e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.92393e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.18857e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.98899e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.31364e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.55751e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.85333e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.90791e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.3581e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.85249e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.16053e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.79933e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.10791e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.36043e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.171e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.5502e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.74843e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.54446e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.43518e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.3036e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.58694e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.52143e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.66717e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.13401e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.12054e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.4283e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.40088e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.44654e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.25752e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.46241e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.10357e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.38681e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.95147e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.78083e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.02543e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.22749e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.03829e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.0085e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.0523e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.07214e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.00302e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.97816e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.54399e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.2155e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.84407e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.27668e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.86607e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.85243e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.63161e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.37837e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.1678e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.53289e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.57313e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.60924e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.73536e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.62373e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.26082e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.22455e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.2077e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.37105e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.69341e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.97122e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.16309e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.78982e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.03271e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.37285e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.82714e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.52466e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.99129e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.94305e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.24566e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.62682e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.52151e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.24154e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.97407e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.49836e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.58667e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.49761e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.41337e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.70052e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.77743e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.9609e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.66006e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.90332e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.8992e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.6846e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.39262e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.46492e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.36316e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.3975e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.18084e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.73942e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.3071e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.2307e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.05985e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.33924e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.81886e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.22253e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.29043e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.76051e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.80218e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.01392e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.01016e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.00036e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.13688e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.65867e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.06205e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.61672e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.72005e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.18107e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.39289e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.76082e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.23364e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.70859e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.04955e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.49882e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.33892e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.36093e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.92666e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.49065e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.42599e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.78119e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.42458e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.6171e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.77839e-24): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.17577e-21): result may not be accurate.

# %% [markdown]
# Как можно убедиться на этом примере, числа обусловленности практически не зависят от порядка матриц, они, скорее всего, зависят от диапазона значений элементов матрицы. Следующий пример:

# %%
C=np.array([[10e13,10e16],[4,1]])
np.linalg.cond(C)
# Out:
# 2.500627656914229e+16

# %% [markdown]
# Как мы видим матрица второго порядка, но число обусловленности довольно большое

# %%
plt.plot(demension, times,'.r', label = 'cond')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %%
plt.plot(demension, times1 , '.b', label ='solve')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %% [markdown]
# Как мы видим функция `cond` отработала в среднем за такое же время, что и в других экспериментах. Вполне логично что время работы функция `cond` не зависит от величины числа обусловленности.
# Время работы функции `solve` cтабильно. Так же можно сделать вывод, что время ёё работы не зависит от числа обусловленности.
# Из экспериментов следует, что время работы этих функций зависит от порядка матрицы.

# %%
plt.semilogy(demension, errors,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина относительной ошибки")
plt.title("Зависимость")
pass

# %% [markdown]
# Величина относительной ошибки очень большая, следовательно, для плохо обусловленных матриц в арифметике с палавающей запятой решение не может быть найдено с хорошей точностью ни одним алгоритмом.

# %%
plt.plot(demension, discr,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина критерия невязки")
plt.title("Зависимость")
pass

# %% [markdown]
# Величина относительной ошибки порядка $10^{-13}$.
