# %% [markdown]
# # Хорошо обусловленные матрицы

# %% [markdown]
# Сначала рассмотрим следующий класс матриц:
# $A=LU$, где $L$, $U$ – случайные нижняя треугольная и верхняя треугольная
# матрицы соответственно с диагональным преобладанием.

# %%
import time
import numpy as np
from numpy import random
import scipy.linalg as linalg
import matplotlib.pyplot as plt
# %matplotlib inline
 
demension= np.arange(10, 1000, 5) #порядки матриц используемые в соотвествующих тестах
conds = [] # для запоминания чисел обусловленности
times = [] # для времени работы cond
times1 = []# для времени работы solve
errors = [] # для относительной ошибки решения
discr = [] # для вычисления критерия невязки решения
for n in demension:
    B = np.random.uniform(-50, 50, (n,n))
    L=np.tril(B)
    B = np.random.uniform(-50, 50, (n,n))
    U=np.triu(B)
    for j in range(0,n): # получение диагонального преобладания
        L[j][j]=n*np.random.uniform(60,200)
    for j in range(0,n): # получение диагонального преобладания
        U[j][j]=n*np.random.uniform(60,200)
    A=L@U
    start = time.monotonic() #замер времени
    cond=np.linalg.cond(A)  # вычисление числа обусловленности
    t=time.monotonic()-start
    conds.append(cond)
    times.append(t)
    x_prec = random.rand(n)#создание случайного вектора x_prec
    b=A@x_prec #генерация правой части системы линейных уравнений
    start=time.monotonic()
    x_comp=linalg.solve(A,b) # решение системы Ax=b
    t = time.monotonic()-start
    times1.append(t)
    error=linalg.norm(x_comp-x_prec)/linalg.norm(x_prec) # вычисление относительной ошибки
    errors.append(error)
    r=linalg.norm(A.dot(x_comp) - b)/linalg.norm(b) #вычисление критерия невязки решения
    discr.append(r)
    
plt.figure(figsize=(10,5))    
plt.semilogy(demension,conds,'.')
plt.xlabel('Порядок матрицы')
plt.ylabel('Числа обусловленности')
plt.title('Зависимость числа обусловленности от порядка матрицы')
pass

# %% [markdown]
# *Числом обусловленности* невырожденной матрицы $A$ называется
# $$
# { cond } А = \| A \|  \cdot \| A^{-1} \|.
# $$
# Если матрица $A$ вырождена, то полагают ${\rm cond} A = \infty$.
# $$
# {\rm cond} A =  {\max_{x\ne 0} \frac{\|A x\|}{\|x\|}} \left/ \,{\min_{x\ne 0}\frac{\|A x\|}{\|x\|}} \right..
# $$
# Таким образом, число обусловленности – это отношение максимального растяжения матрицы к ее минимальному растяжению.
# Число обсуловленности можно рассматривать как меру близости матрицы к вырожденной. Чем больше число обусловленности, тем матрица ближе к вырожденной.
#
# Т.к. число обусловленности матрицы это отношение минимального растяжения к минимальному, то можно сделать вывод, что оно напрямую зависит от порядка матрицы и от диапазона элементов матрицы. Т.е. чем больше порядок матрицы и диапазон её элементов, тем вероятнее что число её обусловленности будет выше, однако не всегда.
#
# Можно наблюдать в выше приведённом графике, что на матрицах малого порядка, число обусловленности крайне мало, но с ростом порядка матриц начало расти и число обусловленности. Это можно объяснить тем, что чем больше порядок матриц, тем больше строк, чем больше строк, тем больше вероятность того, что  $  {\max_{x\ne 0} \frac{\|A x\|}{\|x\|}}.$ будет больше и ${\min_{x\ne 0}\frac{\|A x\|}{\|x\|}}.$ , будет меньше. А тогда их отношение будет больше, и по определению число обусловленности будет больше.

# %%
plt.plot(demension, times,'.r', label = 'cond')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %%
plt.figure(figsize=(10,5))
plt.plot(demension, times1 , '.b', label ='solve')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %% [markdown]
# Такие резльутаты времени работы этих функций вполне очевидны. Так как функция `cond` считает сумму элементов каждой строки и каждый раз сравнивает её с максимальной и минмальной суммой, то примерная сложность работы алгоритма составляет $n^2$.
#
# Функция `solve` решает с.л.у. методом Гаусса, асимптотика примерно $\frac{n^3}{2}$, что эквивалетно $n^3$, но из-за того, что `scipy.linalg` всегда скомпилирована с поддержкой BLAS/LAPACK, то она может работать быстрее, что и видно на графике.

# %%
plt.semilogy(demension, errors,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина относительной ошибки")
plt.title("Зависимость")
pass

# %% [markdown]
# Пусть $x$ – некоторый вектор в ${\bf R}^n$, а $\widetilde{x}$ – другой вектор в ${\bf R}^n$, рассматриваемый как приближение к $x$. Тогда *абсолютной ошибкой* называется число
# $$
#    \|\Delta x\| = \|\widetilde{x} - x\|,
# $$
# а *относительной ошибкой* - число
# $$
#    \frac{\|\Delta x\|}{\|x\|} = \frac{\|\widetilde{x} - x\|}{\|x\|}.
# $$
# Из графика видно, что чем больше порядок матрицы, тем больше относительная ошибка. Это Объясняется тем, что числа нецелые. Чем больше порядок, тем больше накопление ошибок округления. Следовательно и относительная ошибка будет больше. Так же следует, что чем больше порядок матрицы, тем меньше вероятность, что компьютер решит её верно.
#
# Хотя, как можно заметить, для хорошо обусловленных матриц относительная ошибка сравнительно невелика невелика.
#
# Оказывается, что в методе Гаусса с выбором ведущего элемента по столбцу эквивалентное возмущение примерно равно $C\cdot \varepsilon_{\rm M}$, где $C$ – некоторая константа, обычно не сильно превосходящая $1$.
# Таким образом,
# $$
# \frac{\| \Delta x \|}{\| x \|} \approx C\cdot {\rm cond} A \cdot \varepsilon_{\rm M}.
# $$
# В нашем случае, при $\varepsilon_{\rm M} \approx 10^{-16}$ и ${\rm cond} A \approx
# 10^{-1}$ получим относительную ошибку около ${\rm cond} A \cdot \varepsilon_{\rm M}\approx 10^{-15}$, т.е. примерно $15$ правильных значащих цифр.

# %%
plt.plot(demension, discr,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина критерия невязки")
plt.title("Зависимость")
pass

# %% [markdown]
# Относительная невязка $\|Ax - b\|/\|b\|$ для случайных с.л.у. $Ax=b$ от числа неизвестных.
# Исходя из графиков можно заметить, что при увелчении порядка матрицы растёт и относительная невязка. Она напрямую свзязана с относительной ошибкой. Так как из-за возникновения округления решений, будем меняться и правая часть c.л.у. b. И чем больше было неточных округлений, тем больше будет разница $\|Ax - b\|/\|b\|$.
# Число обусловленности растет не очень сильно для данных матриц. Для $n=1000$ оно достигает значения порядка $10^1$. Как следствие, получаем небольшие относительные ошиибки порядка $10^{-16}$. Относительные невязки не првеосходят по порядку величины $10^{-15}$.

# %% [markdown]
#  Теперь рассмотрим:  $A=LL^T$, где $L$ – случайные нижняя треугольная матрица с диагональным преобладанием.

# %%
demension= np.arange(10, 1000, 5) #порядки матриц используемые в соотвествующих тестах
conds = [] # для запоминания чисел обусловленности
times = [] # для времени работы cond
times1 = []# для времени работы solve
errors = [] # для относительной ошибки решения
discr = [] # для вычисления критерия невязки решения
for n in demension:
    B = np.random.uniform(-50, 50, (n,n))
    L=np.tril(B)
    for j in range(0,n): # получение диагонального преобладания
        L[j][j]=n*np.random.uniform(60,200)
    A=L@L.T
    start = time.monotonic() #замер времени
    cond=np.linalg.cond(A)  # вычисление числа обусловленности
    t=time.monotonic()-start
    conds.append(cond)
    times.append(t)
    x_prec = random.rand(n)#создание случайного вектора x_prec
    b=A@x_prec #генерация правой части системы линейных уравнений
    start=time.monotonic()
    x_comp=linalg.solve(A,b) # решение системы Ax=b
    t = time.monotonic()-start
    times1.append(t)
    error=linalg.norm(x_comp-x_prec)/linalg.norm(x_prec) # вычисление относительной ошибки
    errors.append(error)
    r=linalg.norm(A.dot(x_comp) - b)/linalg.norm(b) #вычисление критерия невязки решения
    discr.append(r)
    
plt.figure(figsize=(10,5))    
plt.semilogy(demension,conds,'.')
plt.xlabel('Порядок матрицы')
plt.ylabel('Числа обусловленности')
plt.title('Зависимость числа обусловленности от порядка матрицы')
pass

# %% [markdown]
# Числа обусловленности класса матриц $A=LL^T$ ничем не отличаются от чисел обусловленности класса матриц $A=LU$, где $L$ и $U$ нижняя треугольная и верхняя треугольная матрицы с диагональным преобладанием.

# %%
plt.plot(demension, times,'.r', label = 'cond')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %%
plt.plot(demension, times1 , '.b', label ='solve')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %% [markdown]
# Функция `solve` в среднем отработала за такое же время, что и для класса матриц $A=LU$.Функция `cond` отработала за такое же время.

# %%
plt.semilogy(demension, errors,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина относительной ошибки")
plt.title("Зависимость")
pass

# %% [markdown]
# Так как число обусловленности такое же, как и для $A=LU$, примерно $10^1$, то и величина относительной ошибки такая же, не превосходит $10^{-15}$

# %%
plt.plot(demension, discr,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина критерия невязки")
plt.title("Зависимость")
pass

# %% [markdown]
# Относительные невязки не првеосходят по порядку величины $10^{-15}$.

# %% [markdown]
# # Плохо обусловленые матрицы

# %% [markdown]
# Рассмотрим: $A=LU$, где $L$, $U$ – случайные нижняя треугольная и верхняя треугольная
# матрицы соответственно с малыми диагональными элементами.

# %%
demension= np.arange(10, 1000, 5) #порядки матриц используемые в соотвествующих тестах
conds = [] # для запоминания чисел обусловленности
times = [] # для времени работы cond
times1 = []# для времени работы solve
errors = [] # для относительной ошибки решения
discr = [] # для вычисления критерия невязки решения
for n in demension:
    B = np.random.uniform(-50, 50, (n,n))
    L=np.tril(B)
    B = np.random.uniform(-50, 50, (n,n))
    U=np.triu(B)
    A=L@U
    start = time.monotonic() #замер времени
    cond=np.linalg.cond(A)  # вычисление числа обусловленности
    t=time.monotonic()-start
    conds.append(cond)
    times.append(t)
    x_prec = random.rand(n)#создание случайного вектора x_prec
    b=A@x_prec #генерация правой части системы линейных уравнений
    start=time.monotonic()
    x_comp=linalg.solve(A,b) # решение системы Ax=b
    t = time.monotonic()-start
    times1.append(t)
    error=linalg.norm(x_comp-x_prec)/linalg.norm(x_prec) # вычисление относительной ошибки
    errors.append(error)
    r=linalg.norm(A.dot(x_comp) - b)/linalg.norm(b) #вычисление критерия невязки решения
    discr.append(r)
    
plt.figure(figsize=(10,5))    
plt.semilogy(demension,conds,'.')
plt.xlabel('Порядок матрицы')
plt.ylabel('Числа обусловленности')
plt.title('Зависимость числа обусловленности от порядка матрицы')
pass
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.6375e-18): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.50843e-18): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.2585e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.04485e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.98673e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.57862e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.7692e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.56716e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.15361e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.12314e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.85393e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.31934e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.67885e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.10106e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.0807e-19): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.21031e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.06776e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.52754e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.12596e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.65547e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.82521e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.0634e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.22215e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.11691e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.78624e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.55954e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.36403e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.88686e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.27979e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.568e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.44476e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.81884e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.55863e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.74569e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.21938e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.21888e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.35172e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.19045e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.12143e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.25162e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.28367e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.12487e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.14739e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.95889e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.93692e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.42758e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.59043e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.07964e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.14702e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.9429e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.35465e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.19799e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.12625e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.36941e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.37039e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.75492e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.80543e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.38615e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.0123e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.03568e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.20846e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.01624e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.23333e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.16511e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.2888e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.92161e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.77587e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.1316e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.00836e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.80167e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.21133e-20): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.65439e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.879e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.9512e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.86328e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.99967e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.58578e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.58881e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.60404e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.8957e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.43661e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.27786e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.98608e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.58053e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.27479e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.77593e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.71465e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.2209e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.74111e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.3004e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.869e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.21609e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.03744e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.92674e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.03653e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.08486e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.38748e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.95347e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.52684e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.22588e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.73572e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.95912e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.27116e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.67163e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.82658e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.12801e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.83859e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.94628e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.17839e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.01504e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.01873e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.58074e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.80287e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.65066e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.34924e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.88624e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.17221e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.75556e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.51665e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.3087e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.44092e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.55511e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.79051e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.3521e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.49449e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.56849e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.59655e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.39411e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.8297e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.28138e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.04141e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.91912e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.74283e-24): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.40105e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.68839e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.03254e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.05192e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.53396e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.13743e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.51813e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.87123e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.0115e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.45941e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.07673e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.87576e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.39422e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.08044e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.66686e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.60558e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.04172e-24): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.13674e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.03529e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.37529e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.73164e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.79279e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.27335e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.3086e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.08763e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.51181e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=9.91015e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.19708e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.19046e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.86428e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.83154e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.06276e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.08757e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.24191e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.86633e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.17333e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.95904e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=8.09774e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.8652e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.96046e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.39909e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.43366e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.12231e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.14727e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.86913e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.89451e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.7627e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.26337e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=5.86895e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=2.3893e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.67266e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.64073e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.19826e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.23127e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.30721e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=7.93019e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=6.49013e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=4.01866e-23): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.46778e-21): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=1.92549e-22): result may not be accurate.
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: LinAlgWarning: Ill-conditioned matrix (rcond=3.61786e-21): result may not be accurate.

# %% [markdown]
# Как можно убедиться на этом примере, числа обусловленности практически не зависят от порядка матриц, они, скорее всего, зависят от диапазона значений элементов матрицы. Следующий пример:

# %%
C=np.array([[10e13,10e16],[4,1]])
np.linalg.cond(C)
# Out:
# 2.500627656914229e+16

# %% [markdown]
# Как мы видим матрица второго порядка, но число обусловленности довольно большое

# %%
plt.plot(demension, times,'.r', label = 'cond')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %%
plt.plot(demension, times1 , '.b', label ='solve')
plt.legend(loc = 'best', framealpha = 1)
plt.xlabel("Порядок матрицы")
plt.ylabel("Время работы функции")
plt.title("Зависимость")
pass

# %% [markdown]
# Как мы видим функция `cond` отработала в среднем за такое же время, что и в других экспериментах. Вполне логично что время работы функция `cond` не зависит от велечины числа обусловленности.
#
# Время работы функции `solve` cтабильно.

# %%
plt.semilogy(demension, errors,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина относительной ошибки")
plt.title("Зависимость")
pass

# %% [markdown]
# Величина относительной ошибки очень большая, следовательно, для плохо обусловленных матриц в арфиметике с палавающей запятой решение не может быть найдено с хорошей точностью ни одним алгоритмом.

# %%
plt.plot(demension, discr,'.r')
plt.xlabel("Порядок матрицы")
plt.ylabel("Величина критерия невязки")
plt.title("Зависимость")
pass

# %% [markdown]
# Величина относительной ошибки порядка $10^{-12}$.
